# %% [markdown]
# ## Using pymongo
#
# #### Import the books json files to the mongoDB server
# * Start the mongoDB server
# * Check that there are no existing bookdb database
# * Remove any bookdb database if it exists
# * Use monoimport to import the books.json file into the mongoDB server.
# * ``` mongoimport --db booksdb --collection books --file c:\data\books.json ```
#
#
# #### Installing pyMongo in jupyter notebook
# For anaconda : open anaconda prompt, type conda install -c anaconda pymongo
#
#
# #### Connecting to the mongoDB database using pymongo
#
# ```
# from pymongo import MongoClient
#
# #connect the client(program) to a mongoDB server
# client = MongoClient("localhost", 27017)
#
# #list databases in your mongoDB server
# dbs = client.list_database_names()
# for d in dbs:
#     print(d)
# print(client.database_names())  #deprecated method - use list_database_names
# ```
# #### Exercise 1
# Copy the above code and run it! Make sure you have pymongo install in your jupyter notebook!

# %%
from pymongo import MongoClient

client = MongoClient("localhost", 27017)

dbs = client.list_database_names()
for d in dbs:
    print(d)
print(client.database_names())
client.close()
# Out:
# admin
# local
# ['admin', 'local']

# %%
#Additional personal note (use list_database_names() 
#                          instead of database_names)

from pymongo import MongoClient

client = MongoClient("localhost", 27017)
databases = client.list_database_names()
db = client['booksdb'] 
colls = db.list_collection_names()
print(databases)
print(colls)
client.close()
# Out:
# ['admin', 'booksdb', 'local']
# ['books']

# %% [markdown]
# #### Creating Collection using pymongo
#
# ```
# from pymongo import MongoClient
#
# #connect the client(program) to a mongoDB server
# client = MongoClient("localhost", 27017)
#
# mydb = client["mydatabase"]   ## use the database mydatabase
# mycoll = mydb["customers"]    ## get the collection - customers
# client.close()
# ```
# #### Dropping Collection using pymongo
#
# ```
# from pymongo import MongoClient
#
# #connect the client(program) to a mongoDB server
# client = MongoClient("localhost", 27017)
#
# mydb = client["mydatabase"]   ## use the database mydatabase
# mycoll = mydb["customers"]    ## get the collection - customers
# mycoll.drop()
# client.close()
# ```
# #### Exercise 2 :
#
# Copy the above code and run it!  You can try dropping some of the collections you have created in your mongoDB server!

# %%
##Does not output anything as database is only created when a document is added into a collection in the db

import pymongo

client = pymongo.MongoClient("localhost", 27017)
mydb = client["mydatabase"]
mycoll = mydb["customers"]
print(mydb.list_collection_names())
mycoll.drop()
print(mydb.list_collection_names())
client.close()
# Out:
# []
# []

# %% [markdown]
# #### List the collections in the database
#
# ```
# from pymongo import MongoClient
#
# #connect the client(program) to a mongoDB server
# try:
#     client = MongoClient("localhost", 27017)
#     print("Connected")
# except:
#     print("Cannot connect to database")
#
# mydb = client["mydatabase"]   ## use the database mydatabase
# mycoll = mydb["customers"]    ## get the collection - customers
#
# print(mydb.list_collection_names())
# client.close()
#
# ```
# #### Exercise 3
#
# List the collections in the booksdb

# %%
#Pymongo only creates database after a document is inserted into a collection in the database
from pymongo import MongoClient

try:
    client = MongoClient("localhost", 27017)
    print("Connected")
except:
    print("Cannot connect to database")

mydb = client["mydatabase"]
mycoll = mydb["customers"]

print(mydb.list_collection_names())
mydict = { "name": "John", "address": "Highway 37" }

x = mycoll.insert_one(mydict)
client.close()
# Out:
# Connected
# []

# %% [markdown]
# #### Inserting document/s into collection
#
# * Using find() to list documents.
#
# The insert_one() method returns an instance of InsertOneResult, which has a property, inserted_id, that holds the id of the inserted document.
#
#
# ```
# from pymongo import MongoClient
#
# #connect the client(program) to a mongoDB server
# try:
#     client = MongoClient("localhost", 27017)
#     print("Connected")
# except:
#     print("Cannot connect to database")
#
# mydb = client["mydatabase"]   ## use the database mydatabase
# mycoll = mydb["customers"]    ## get the collection - customers
#
# document = {"name":"Peter", "address":"abc def"} ##dictionary
# x=mycoll.insert_one(document)
# print(x.inserted_id)
# client.close()
# ```
# * Using insert_many to insert documents.
#
# The insert_many() method returns an instance of InsertManyResult, which has a property, inserted_ids, that holds the list of ids of the inserted documents
#
# ```
# from pymongo import MongoClient
#
# custList =[
#     {"name": "Amy", "address":"Apple ST 652"},
#     {"name": "Hannah", "address":"Montain 21"},
#     {"name": "Michael", "address":"Valley 345"},
#     {"name": "Sandy", "address":"Ocean blvd 2"},
#     {"name": "Betty", "address":"Green Grass 1"},
#     {"name": "Richard", "address":"Sky st 331"}
# ]
#
# #connect the client(program) to a mongoDB server
# try:
#     client = MongoClient("localhost", 27017)
#     print("Connected")
# except:
#     print("Cannot connect to database")
#
# mydb = client["mydatabase"]   ## use the database mydatabase
# mycoll = mydb["customers"]    ## get the collection - customers
#
# x=mycoll.insert_many(custList)
# print(x.inserted_ids)
# client.close()
# ```
# #### Exercise 4
#
# Copy and try the code above.

# %%
from pymongo import MongoClient

custList =[
    {"name": "Amy", "address":"Apple ST 652"},
    {"name": "Hannah", "address":"Montain 21"},
    {"name": "Michael", "address":"Valley 345"},
    {"name": "Sandy", "address":"Ocean blvd 2"},
    {"name": "Betty", "address":"Green Grass 1"},
    {"name": "Richard", "address":"Sky st 331"}
]

#connect the client(program) to a mongoDB server
try:
    client = MongoClient("localhost", 27017)
    print("Connected")
except:
    print("Cannot connect to database")

mydb = client["mydatabase"]   ## use the database mydatabase
mycoll = mydb["customers"]    ## get the collection - customers

x=mycoll.insert_many(custList)
print(x.inserted_ids)
client.close()
# Out:
# Connected
# [ObjectId('604ae6c0e1c7dd4c1cdf8c14'), ObjectId('604ae6c0e1c7dd4c1cdf8c15'), ObjectId('604ae6c0e1c7dd4c1cdf8c16'), ObjectId('604ae6c0e1c7dd4c1cdf8c17'), ObjectId('604ae6c0e1c7dd4c1cdf8c18'), ObjectId('604ae6c0e1c7dd4c1cdf8c19')]

# %% [markdown]
# #### Exercise 5
#
# Insert the following book to the collections in booksdb.
#
# ```
# { "title" : "Cryptography Demystified", "isbn" : "0071406387", "pageCount" : 356, "thumbnailUrl" : "https://m.media-amazon.com/images/I/710c8mSVe9L._AC_UY218_ML3_.jpg", "status" : "MEAP", "authors" : [ "John Hershey"], "categories" : ['Demystified'] }
#
# ```

# %%
from pymongo import MongoClient

client = MongoClient("localhost", 27017)
mydb = client["booksdb"]
mycoll = mydb["books"]

book = { "title" : "Cryptography Demystified", "isbn" : "0071406387", "pageCount" : 356, "thumbnailUrl" : "https://m.media-amazon.com/images/I/710c8mSVe9L._AC_UY218_ML3_.jpg", "status" : "MEAP", "authors" : [ "John Hershey"], "categories" : ['Demystified'] }

mycoll.insert_one(book)
client.close()

# %% [markdown]
# #### Exercise 6
#
# Insert the following list of books to the collections in booksdb.
#
# ```
# { "title" : "Serious Cryptography: A Practical Introduction to Modern Encryption", "isbn" : "1593278268", "pageCount" : 313, "thumbnailUrl" : "https://m.media-amazon.com/images/I/51wv16GC0FL.jpg", "status" : "MEAP", "authors" : [ "Jean-Philippe Aumasson"], "categories" : [] }
#
# { "title" : "Rootkits and Bootkits: Reversing Modern Malware and Next Generation Threats", "isbn" : "B07P8J5HZJ", "pageCount" : 448, "thumbnailUrl" : "https://m.media-amazon.com/images/I/51+Zko5mWpL.jpg", "status" : "MEAP", "authors" : [ "Alex Matrosov", "Eugene Rodionov", "Sergey Bratus" ], "categories" : ["Viruses & Malware", "Computer Viruses"] }
#
# { "title" : "Understanding Cryptography: A Textbook for Students and Practitioners", "isbn" : "B014P9I39Q", "pageCount" : 390, "thumbnailUrl" : "https://m.media-amazon.com/images/I/61TXcy7R+kL._AC_UY218_ML3_.jpg", "status" : "MEAP", "authors" : [ "Prof. Dr.-Ing. Christof Paar", "Prof. Dr.-Ing. January Pelzl"], "categories" : [" Computer Information Theory", "Encryption"] }
#
# ```

# %%
from pymongo import MongoClient

client = MongoClient("localhost", 27017)
mydb = client["booksdb"]
mycoll = mydb["books"]

books = [
    { "title" : "Serious Cryptography: A Practical Introduction to Modern Encryption", "isbn" : "1593278268", "pageCount" : 313, "thumbnailUrl" : "https://m.media-amazon.com/images/I/51wv16GC0FL.jpg", "status" : "MEAP", "authors" : [ "Jean-Philippe Aumasson"], "categories" : [] }, 
    { "title" : "Rootkits and Bootkits: Reversing Modern Malware and Next Generation Threats", "isbn" : "B07P8J5HZJ", "pageCount" : 448, "thumbnailUrl" : "https://m.media-amazon.com/images/I/51+Zko5mWpL.jpg", "status" : "MEAP", "authors" : [ "Alex Matrosov", "Eugene Rodionov", "Sergey Bratus" ], "categories" : ["Viruses & Malware", "Computer Viruses"] }, 
    { "title" : "Understanding Cryptography: A Textbook for Students and Practitioners", "isbn" : "B014P9I39Q", "pageCount" : 390, "thumbnailUrl" : "https://m.media-amazon.com/images/I/61TXcy7R+kL._AC_UY218_ML3_.jpg", "status" : "MEAP", "authors" : [ "Prof. Dr.-Ing. Christof Paar", "Prof. Dr.-Ing. January Pelzl"], "categories" : [" Computer Information Theory", "Encryption"] }
]

mycoll.insert_many(books)
client.close()

# %% [markdown]
# #### Find document/s in the collection
#
# * Using find() to list the documents in a collection.
#
#     ```
#     from pymongo import MongoClient
#     #connect the client(program) to a mongoDB server
#     try:
#         client = MongoClient("localhost", 27017)
#         print("Connected")
#     except:
#         print("Cannot connect to database")
#
#     mydb = client["mydatabase"]   ## use the database mydatabase
#     mycoll = mydb["customers"]    ## get the collection - customers
#
#     for document in mycoll.find():
#         print(document)
#     client.close()
#
#     ```
#  * List documents with condition/filter.
#
#  ```
#     from pymongo import MongoClient
#     #connect the client(program) to a mongoDB server
#     try:
#         client = MongoClient("localhost", 27017)
#         print("Connected")
#     except:
#         print("Cannot connect to database")
#
#     mydb = client["mydatabase"]   ## use the database mydatabase
#     mycoll = mydb["customers"]    ## get the collection - customers
#
#     myquery = {"address": {"$gt":"S"}}
#     myprojections ={"_id":0}
#     myresult = mycoll.find(myquery, myprojections)
#     for x in myresult:
#         print(x)
#  ```

# %% [markdown]
# #### Exercise 7
# Find books with title containing the word **Hadoop**. Display the result in the following format:
#
# ```
# Title                                    ISBN                                     Author/s
# Hadoop in Action                         1935182196                               Chuck Lam
# Hadoop in Practice                       1617290238                               Alex Holmes
# Hadoop in Practice, Second Edition       1617292222                               Alex Holmes
# ```

# %%
from pymongo import MongoClient

client = MongoClient("localhost", 27017)

db = client['booksdb']
coll = db['books']

myquery = {"title":{"$regex":"Hadoop"}}
myprojection = {"title":1, "isbn":1, "authors":1, "_id":0}

myresult = coll.find(myquery, myprojection)

print("{:<50} {:<20} {:<30}".format("Title", "ISBN", "Author/s"))

for result in myresult:
    print(f"{result['title']:<50} {result['isbn']:<20} {','.join(result['authors']):<30}")
          
client.close()
# Out:
# Title                                              ISBN                 Author/s
# Hadoop in Action                                   1935182196           Chuck Lam
# Hadoop in Practice                                 1617290238           Alex Holmes
# Hadoop in Practice, Second Edition                 1617292222           Alex Holmes

# %%
from pymongo import MongoClient

client = MongoClient("localhost", 27017)
mydb = client["booksdb"]
mycoll = mydb["books"]

myquery = {"title": {'$regex': 'Hadoop'}}
myprojections = {"title":1, "isbn":1, "authors":1, '_id':0}

myresult = mycoll.find(myquery, myprojections)
print('Title                                    ' + 'ISBN                                     ' + 'Author/s')
for x in myresult:
    author = ''
    for a in x['authors']:
        author += a
    print("{:<40} {:<40} {:<10}".format(x['title'],x['isbn'],author))

client.close()
# Out:
# Title                                    ISBN                                     Author/s
# Hadoop in Action                         1935182196                               Chuck Lam
# Hadoop in Practice                       1617290238                               Alex Holmes
# Hadoop in Practice, Second Edition       1617292222                               Alex Holmes

# %% [markdown]
# #### Exercise 8
#
# Find books with title containing the word **Programming**, pageCount is not zero and has author information.
# Display the documents as shown. The document should be sorted by title in ascending order
# and only the first 5 documents are listed.
# ```
# Title                                              ISBN           Author/s
# Distributed Programming with Java                  1884777651     Qusay H. Mahmoud
# Elements of Programming with Perl                  1884777805     Andrew L. Johnson
# Graphics Programming with Perl                     1930110022     Martien Verbruggen
# Java 3D Programming                                1930110359     Daniel Selman
# Java Applets and Channels Without Programming      1884777392     Ronny Richardson,Michael Shoffner,Marq Singer,Bruce Murray,,Jack Gambol
# ```

# %%
from pymongo import MongoClient

client = MongoClient("localhost", 27017)

mycoll = client['booksdb']['books']

myquery = {"$and":[{"title":{"$regex":"Programming"}}, {"pageCount": \
          {"$gt":0}}, {"authors":{"$exists":True}}]}
myprojection = {"title":1, "isbn":1, "authors": 1, "_id":0}

myresult = mycoll.find(myquery, myprojection).sort("title", 1)

print("{:<40} {:<20} {:<30}".format("Title", "ISBN", "Authors"))

count = 0

for line in myresult:
    if len(line['authors']) != 0 and count != 5:
        print(f"{line['title']:<40} {line['isbn']:<20} {','.join(line['authors']):<30}")
        count += 1
    
client.close()
# Out:
# Title                                    ISBN                 Authors
# Distributed Programming with Java        1884777651           Qusay H. Mahmoud
# Elements of Programming with Perl        1884777805           Andrew L. Johnson
# Graphics Programming with Perl           1930110022           Martien Verbruggen
# Java 3D Programming                      1930110359           Daniel Selman
# Java Applets and Channels Without Programming 1884777392           Ronny Richardson,Michael Shoffner,Marq Singer,Bruce Murray,,Jack Gambol

# %%
from pymongo import MongoClient

client = MongoClient("localhost", 27017)
mycoll = client["booksdb"]["books"]


#For $exists, it only checks if the field exists and evals to true
#even if authors = []
myquery = {"$and": [{"title": {"$regex": "Programming"}}, \
            {'pageCount':{"$gt":0}}, {'authors':{"$exists":True}}]}
myprojections = {"title":1, "isbn":1, "authors":1, "_id":0}

results = mycoll.find(myquery, myprojections).sort("title", 1)
print('Title                                    ' + 'ISBN            ' + 'Author/s')
count = 0
for x in results:
    if count < 5:
        if x['authors']:
            author = ''
            for a in x['authors']:
                author += a 
            title = x['title']

            if len(title) > 40:
                length = len(title)
                front = title[:39]
                back = title[39:]
                print("{:<40} {:<15} {:<10}".format(front,x['isbn'],author))
                print(back)
            else:
                print("{:<40} {:<15} {:<10}".format(title,x['isbn'],author))
            
            count += 1
            

client.close()
# Out:
# Title                                    ISBN            Author/s
# Distributed Programming with Java        1884777651      Qusay H. Mahmoud
# Elements of Programming with Perl        1884777805      Andrew L. Johnson
# Graphics Programming with Perl           1930110022      Martien Verbruggen
# Java 3D Programming                      1930110359      Daniel Selman
# Java Applets and Channels Without Progr  1884777392      Ronny RichardsonMichael ShoffnerMarq SingerBruce MurrayJack Gambol
# amming

# %% [markdown]
# #### Update document/s in the collection
#
# * Using update_one() to update the first document that satisfies the query/filterin a collection.
#
#     ```
#     from pymongo import MongoClient
#     #connect the client(program) to a mongoDB server
#     try:
#         client = MongoClient("localhost", 27017)
#         print("Connected")
#     except:
#         print("Cannot connect to database")
#
#     mydb = client["mydatabase"]   ## use the database mydatabase
#     mycoll = mydb["customers"]    ## get the collection - customers
#     myquery = {"address": "Valley 345"}
#     newval = {"$set":{"address":"Canyon 123"}}
#     mycoll.update_one(myquery, newval)
#
#     for document in mycoll.find():
#         print(document)
#     client.close()
#
#     ```
# * Using update_many() to update the all documents that satisfy the query/filter in a collection.
#
#     ```
#     from pymongo import MongoClient
#         #connect the client(program) to a mongoDB server
#     try:
#         client = MongoClient("localhost", 27017)
#         print("Connected")
#     except:
#         print("Cannot connect to database")
#
#     mydb = client["mydatabase"]   ## use the database mydatabase
#     mycoll = mydb["customers"]    ## get the collection - customers
#     myquery = {"name": "Minnies"}
#     newval = {"$set":{"name":"Minnie"}}
#     x = mycoll.update_many(myquery, newval)
#
#     print("No of documents updated : {}".format(x.modified_count))
#
#     client.close()
#     ```

# %% [markdown]
# #### Exercise 9
#
# Find the first book with title containing the word **in Action** and replace the word **Action** to **Motion**.
# Take note that only the word **Action** is replace and not the whole title.
# After the replacement, display the document as follows:
# ```
# Title                                              ISBN           Author/s
# Distributed Programming with Java in Motion        1884777651     Qusay H. Mahmoud
# ```

# %%
from pymongo import MongoClient

client = MongoClient("localhost", 27017)
mydb = client["booksdb"]
mycoll = mydb["books"]

myquery = {'title':{"$regex":"in Action"}}
myprojection = {'title':1, 'isbn':1, 'authors':1, '_id':0}
result = mycoll.find_one(myquery, myprojection)
newTitle = result['title'].replace("Action", "Motion")
newval = {"$set":{"title": newTitle}}
x = mycoll.update_one(myquery, newval)
author = ''
for a in result['authors']:
    author += a


print('Title                                    ' + 'ISBN            ' + 'Author/s')
print("{:<40} {:<15} {:<10}".format(newTitle,result['isbn'],author))

client.close()
# Out:
# Title                                    ISBN            Author/s
# Collective Intelligence in Motion        1933988312      Satnam Alag

# %% [markdown]
# #### Exercise 10
#
# Find the books with "PUBLISH'status and replace the status to "PUBLISHED".
# After the replacement, display the documents as follows:
# ```
# Title                                              ISBN           Author/s
# Distributed Programming with Java in Motion        1884777651     Qusay H. Mahmoud
#         ... ...
#         ... ...
# ```

# %%
from pymongo import MongoClient

client = MongoClient("localhost", 27017)
mycoll = client['booksdb']['books']
myquery = {"status":{"$eq":"PUBLISH"}}
myprojection = {'title': 1, 'isbn': 1, 'authors': 1, '_id': 0}
result = mycoll.find(myquery, myprojection)

# %%
#Test: Whether all the books have isbn

from pymongo import MongoClient

client = MongoClient("localhost", 27017)
mydb = client["booksdb"]
mycoll = mydb["books"]
myquery = {"isbn":{"$exists": True}}
newquery = {}
result = mycoll.find(myquery)
print("books with isbn", result.count())
result2 = mycoll.find(newquery)
print("total books", result2.count())
# Out:
# books with isbn 263
# total books 265

# %%
from pymongo import MongoClient

client = MongoClient("localhost", 27017)
mydb = client["booksdb"]
mycoll = mydb["books"]

myquery = {"status": "PUBLISH"}
myprojection = {'title':1, 'isbn':1, 'authors':1}
newval = {"$set":{"status":"PUBLISHED"}}
x = mycoll.update_many(myquery, newval)
newquery = {"status":"PUBLISHED"}
result = mycoll.find(newquery, myprojection)
print('Title                                    ' + 'ISBN            ' + 'Author/s')
for x in result:
    author = ','.join(x['authors'])
    author = author.replace(',,', ',')
    author = author.replace(',', ', ')
    title = x['title']
    try:
        isbn = '' + x['isbn']           ##Added because two of the books have no isbn, which would have raised error
    except:
        isbn = 'None'
    if len(title) > 40:                #If title exceeds 40, it will go over one line
        front = title[:39]
        back = title[39:]
        if len(author) > 65:
            print("{:<40} {:<15} {:<10}".format(front,isbn,author[:65]))
            print("{:<56} {}".format(back, author[65:]))
        else:
            print("{:<40} {:<15} {:<10}".format(front,isbn,author))
            print(back)
    else:
        if len(author) > 65:
            print("{:<40} {:<15} {:<10}".format(title,isbn,author[:65]))
            print("{:<56} {}".format('', author[65:]))
        else:
            print("{:<40} {:<15} {:<10}".format(title,isbn,author))
    
client.close()
# Out:
# Title                                    ISBN            Author/s
# Android in Motion, Second Edition        1935182722      W. Frank Ableson, Robi Sen
# Collective Intelligence in Motion        1933988312      Satnam Alag
# Flex 3 in Action                         1933988746      Tariq Ahmed with Jon Hirschi, Faisal Abid
# Zend Framework in Action                 1933988320      Rob Allen, Nick Lo, Steven Brown
# Unlocking Android                        1933988673      W. Frank Ableson, Charlie Collins, Robi Sen
# Coffeehouse                              1884777384      Levi Asher, Christian Crumlish
# Hello! Flex 4                            1933988762      Peter Armstrong
# OSGi in Depth                            193518217X      Alexandre de Castro Alves
# Flexible Rails                           1933988509      Peter Armstrong
# Griffon in Action                        1935182234      Andres Almiray, Danno Ferrin, James Shingler
# Team Foundation Server 2008 in Action    1933988592      Jamil Azher
# Distributed Application Development wit  1884777686      Michael J. Barlotta
# h PowerBuilder 6.0
# Brownfield Application Development in .  1933988711      Kyle Baley, Donald Belcham
# NET
# Flex 4 in Action                         1935182420      Tariq Ahmed, Dan Orlando, John C. Bland II, Joel Hooks
# Flex on Java                             1933988797      Bernerd Allmon, Jeremy Anderson
# Jaguar Development with PowerBuilder 7   1884777864      Michael Barlotta
# Taming Jaguar                            1884777686      Michael J. Barlotta, Jason R. Weiss
# Hibernate in Action (Chinese Edition)    None            Christian Bauer, Gavin King
# 3D User Interfaces with Java 3D          1884777902      Jon Barrilleaux
# Hibernate in Action                      193239415X      Christian Bauer, Gavin King
# JSTL in Action                           1930110529      Shawn Bayern
# Java Persistence with Hibernate          1932394885      Christian Bauer, Gavin King
# iBATIS in Action                         1932394826      Clinton Begin, Brandon Goodin, Larry Meadors
# Designing Hard Software                  133046192       Douglas W. Bennett
# Hibernate Search in Action               1933988649      Emmanuel Bernard, John Griffin
# jQuery in Action                         1933988355      Bear Bibeault, Yehuda Katz
# jQuery in Action, Second Edition         1935182323      Bear Bibeault, Yehuda Katz
# Ruby for Rails                           1932394699      David A. Black
# Building Secure and Reliable Network Ap  1884777295      Kenneth P. Birman
# plications
# Website Owner's Manual                   1933988452      Paul A. Boag
# ASP.NET 4.0 in Practice                  1935182463      Daniele Bochicchio, Stefano Mostarda, Marco De Sanctis
# The Well-Grounded Rubyist                1933988657      David A. Black
# Hello! Python                            1935182080      Anthony Briggs
# PFC Programmer's Reference Manual        1884777554      Richard Brooks
# iOS in Practice                          1617291269      Bear P. Cahill
# Graphics File Formats                    133034054       C. Wayne Brown, Barry J. Shepherd
# Visual Object Oriented Programming       131723979       Margaret M. Burnett, Adele Goldberg, Ted G. Lewis
# iPhone in Action                         193398886X      Christopher Allen, Shannon Appelcline
# Internet and Intranet Applications with  1884777600      Tom Cervenka
#  PowerBuilder 6
# Silverlight 2 in Action                  1933988428      Chad A. Campbell, John Stockton
# The Quick Python Book, Second Edition    193518220X      Naomi R. Ceder
# Practical Methods for Your Year 2000 Pr  188477752X      Robert Chapman
# oblem
# Mobile Agents                            1884777368      William R. Cockayne and Michael Zyda, editors
# Spring Dynamic Modules in Action         1935182307      Arnaud Cogoluegnes, Thierry Templier, Andy Piper
# SQL Server 2008 Administration in Action 193398872X      Rod Colledge
# Android in Practice                      1935182927      Charlie Collins, Michael D. Galpin, Matthias Kaeppler
# Object Oriented Perl                     1884777791      Damian Conway
# GWT in Practice                          1933988290      Robert Cooper, Charles Collins
# Ajax in Action                           1932394613      Dave Crane, Eric Pascarello with Darren James
# Ajax in Practice                         1932394990      Dave Crane, Jord Sonneveld and Bear Bibeault with Ted Goddard, Ch
#                                                          ris Gray, Ram Venkataraman, Joe Walker
# Prototype and Scriptaculous in Action    1933988037      Dave Crane, Bear Bibeault with Tom Locke
# POJOs in Action                          1932394583      Chris Richardson
# Data Munging with Perl                   1930110006      David Cross
# Hello! HTML5 & CSS3                      1935182897      Rob Crowther
# Wicket in Action                         1932394982      Martijn Dashorst, Eelco Hillenius
# Open Source SOA                          1933988541      Jeff Davis
# Seam in Action                           1933988401      Dan Allen
# Struts 2 in Action                       193398807X      Donald Brown, Chad Michael Davis, Scott Stanlick
# Essential Guide to Peoplesoft Developme  1884777929      Tony DeLia, Galina Landres, Isidor Rivera, Prakash Sankaran
# nt and Customization
# .NET Multithreading                      1930110545      Alan Dennis
# Spring Roo in Action                     193518296X      Ken Rimple, Srini Penchikala
# SCWCD Exam Study Kit Second Edition      1932394389      Hanumant Deshmukh, Jignesh Malavia, Matthew Scarpino
# RSS and Atom in Action                   1932394494      Dave Johnson
# LDAP Programming, Management and Integr  1930110405      Clayton Donley
# ation
# Java Foundation Classes                  1884777678      Stephen C. Drye, William C. Wake
# Mule in Action                           1933988967      David Dossot, John D'Emic
# Python and Tkinter Programming           1884777813      John E. Grayson
# Microsoft.NET for Programmers            1930110197      Fergal Grimes
# Grails in Action                         1933988932      Glen Smith, Peter Ledbrook
# OSGi in Action                           1933988916      Richard S. Hall, Karl Pauls, Stuart McCulloch, David Savage
# GWT in Action                            1933988231      Robert Hanson, Adam Tacy
# Java Development with Ant                1930110588      Erik Hatcher, Steve Loughran
# SharePoint 2010 Site Owner's Manual      1933988754      Yvonne M. Harryman
# The Quick Python Book                    1884777740      Daryl Harms, Kenneth McDonald
# Lucene in Action                         1932394281      Erik Hatcher, Otis Gospodnetic
# Lucene in Action, Second Edition         1933988177      Erik Hatcher, Otis Gospodnetic, Michael McCandless
# PowerBuilder 6.0 Questions & Answers     1884777708      Tim Hatton
# The Awesome Power of PowerJ              1884777538      Tim Hatton
# The Awesome Power of Power++             1884777546      Tim Hatton
# Azure in Action                          193518248X      Chris Hay, Brian H. Prince
# Code Generation in Action                1930110979      Jack Herrington
# Illustrated Guide to HTTP                138582262       Paul S. Hethmon
# Java Network Programming, Second Edition 188477749X      Merlin Hughes, Michael Shoffner, Derek Hamner
# Portlets and Apache Portals              None            Stefan Hepper, Peter Fischer, Stephan Hesmer, Richard Jacob, Davi
#                                                          d Sean Taylor
# Struts in Action                         1932394249      Ted N. Husted, Cedric Dumoulin, George Franciscus, David Winterfe
#                                                          ldt
# Taming Text                              193398838X      Grant S. Ingersoll, Thomas S. Morton, Andrew L. Farris
# Camel in Action                          1935182366      Claus Ibsen, Jonathan Anstey
# JBoss in Action                          1933988029      Javid Jamae, Peter Johnson
# Extending and Embedding Perl             1930110820      Tim Jenness, Simon Cozens
# Gnuplot in Action                        1933988398      Philipp K. Janert
# Elements of Programming with Perl        1884777805      Andrew L. Johnson
# iOS 4 in Action                          1617290017      Jocelyn Harrington, Brandon Trebitowski, Christopher Allen, Shann
#                                                          on Appelcline
# SOA Security                             1932394680      Ramarao Kanneganti, Prasad A. Chodavarapu
# R in Action                              1935182390      Robert I. Kabacoff
# Rails 3 in Action                        1935182277      Ryan Bigg, Yehuda Katz
# Continuous Integration in .NET           1935182552      Marcin Kawalerowicz, Craig Berntson
# Technology Paradise Lost                 1932394133      Erik Keller
# Laszlo in Action                         1932394834      Norman Klein, Max Carlson with Glenn MacEwen
# Groovy in Action                         1932394842      Dierk Koenig with Andrew Glover, Paul King, Guillaume Laforge, Jo
#                                                          n Skeet
# Effective Unit Testing                   1935182579      Lasse Koskela
# Object Technology Centers of Excellence  132612313       Timothy D. Korson, Vijay K. Vaishnavi
# Test Driven                              1932394850      Lasse Koskela
# Practical Software Requirements          1884777597      Benjamin L. Kovitz
# The Awesome Power of Direct3D/DirectX    1884777473      Peter J. Kovach
# NHibernate in Action                     1932394923      Pierre Henri Kuate, Tobin Harris, Christian Bauer, Gavin King
# Microsoft Reporting Services in Action   1932394222      Teo Lachev
# AspectJ in Action                        1930110936      Ramnivas Laddad
# SQR in PeopleSoft and Other Applications 1884777775      Galina, Vlad Landres
# Tuscany SCA in Action                    1933988894      Simon Laws, Mark Combellack, Raymond Feng, Haleh Mahbod, Simon Na
#                                                          sh
# Up to Speed with Swing, Second Edition   1884777759      Steven Gutz
# Hadoop in Action                         1935182196      Chuck Lam
# AspectJ in Action, Second Edition        1933988053      Ramnivas Laddad
# SQR in PeopleSoft and Other Application  1932394001      Galina Landres, Vlad Landres
# s, Second Edition
# WebWork in Action                        1932394532      Patrick Lightbody, Jason Carreira
# Object Oriented Application Frameworks   1884777066      Ted Lewis, friends
# Tapestry in Action                       1932394117      Howard M. Lewis Ship
# SharePoint 2007 Developer's Guide to Bu  1933988819      Brett Lonsdale, Nick Swan
# siness Data Catalog
# Client/Server Yellow Pages               1884777082      Compiled, introduced by Ted Lewis
# Erlang and OTP in Action                 1933988789      Martin Logan, Eric Merritt, Richard Carlsson
# Doing IT Right                           133964256       Harold Lorin
# SNA and TCP/IP Enterprise Networking     131271687       Daniel C. Lynch, James P. Gray, and Edward Rabinovitch, editors
# Subversion in Action                     1932394478      Jeffrey Machols
# Adobe AIR in Action                      1933988487      Joey Lott, Kathryn Rotondo, Sam Ahn, Ashley Atkins
# iText in Action                          1932394796      Bruno Lowagie
# Restlet in Action                        193518234X      Jerome Louvel, Thierry Boileau, Philippe Mougin
# Minimal Perl                             1932394508      Tim Maher
# Distributed Programming with Java        1884777651      Qusay H. Mahmoud
# Ant in Action                            193239480X      Steve Loughran, Erik Hatcher
# JavaServer Faces in Action               1932394125      Kito D. Mann
# Comprehensive Networking Glossary and A  013319955X      Gary Scott Malkin
# cronym Guide
# Power-3D                                 138412146       Kyle Lussier
# LINQ in Action                           1933988169      Fabrice Marguerie, Steve Eichert, Jim Wooley
# iText in Action, Second Edition          1935182617      Bruno Lowagie
# Internet BBSs                            132869985       Richard Scott Mark
# JUnit in Action                          1930110995      Vincent Massol with Ted Husted
# Algorithms of the Intelligent Web        1933988665      Haralambos Marmanis, Dmitry Babenko
# Ruby in Practice                         1933988479      Jeremy McAnally, Assaf Arkin
# Maximum MIDI                             1884777449      Paul Messick
# Inside LotusScript                       1884777481      Joe McGinn
# Planning and Managing ATM Networks       132621894       Daniel Minoli, Thomas W. Golway, Norris P. Smith
# Client/Server Applications on ATM Netwo  137353006       Daniel Minoli, Andrew Schmidt
# rks
# JavaFX in Action                         1933988991      Simon Morris
# Entity Framework 4 in Action             1935182188      Stefano Mostarda, Marco De Sanctis, Daniele Bochicchio
# ASP.NET 2.0 Web Parts in Action          193239477X      Darren Neimke
# Core OWL 5.0                             1884777503      Ted Neward
# Server-Based Java Programming            1884777716      Ted Neward
# Sass and Compass in Action               1617290149      Wynn Netherland, Nathan Weizenbaum, Chris Eppstein, Brandon Mathi
#                                                          s
# SQL Server MVP Deep Dives                9781935182047   Paul Nielsen, Kalen Delaney, Greg Low, Adam Machanic, Paul S. Ran
#                                                          dal, Kimberly L. Tripp
# Advanced OWL 5.0                         1884777465      Ted Neward
# SQL Server MVP Deep Dives                1935182048      Contributions from 53 SQL Server MVPs, Edited by Paul Nielsen, Ka
#                                                          len Delaney, Greg Low, Adam Machanic, Paul S. Randal, Kimberly L. Tripp
# SQL Server MVP Deep Dives                9781935182047   Contributions from 53 SQL Server MVPs; Edited by Paul Nielsen, Ka
#                                                          len Delaney, Greg Low, Adam Machanic, Paul S. Randal, Kimberly L. Tripp
# Mahout in Action                         1935182684      Sean Owen, Robin Anil, Ted Dunning, Ellen Friedman
# Programming Mac OS X                     1930110855      Kevin O'Malley
# PostGIS in Action                        1935182269      Regina O. Obe, Leo S. Hsu
# The Art of Unit Testing                  1933988274      Roy Osherove
# ASP.NET MVC in Action                    1933988622      Jeffrey Palermo, Ben Scheirman, Jimmy Bogard
# ASP.NET MVC 2 in Action                  193518279X      Jeffrey Palermo, Ben Scheirman, Jimmy Bogard, Eric Hexter, Matthe
#                                                          w Hinze
# EJB 3 in Action                          1933988347      Debu Panda, Reza Rahman, Derek Lane
# ASP.NET MVC 4 in Action                  1617290416      Jeffrey Palermo, Jimmy Bogard, Eric Hexter, Matthew Hinze, Jeremy
#                                                           Skinner
# Practical LotusScript                    1884777767      Anthony Patton
# Domino Development with Java             1930110049      Anthony Patton
# Explorer's Guide to the Semantic Web     1932394206      Thomas B. Passin
# Windows PowerShell in Action             1932394907      Bruce Payette
# Silverlight 5 in Action                  1617290319      Pete Brown
# Windows PowerShell in Action, Second Ed  1935182137      Bruce Payette
# ition
# Hibernate Quickly                        1932394419      Patrick Peak, Nick Heudecker
# Silverlight 4 in Action, Revised Edition 1935182374      Pete Brown
# Lift in Action                           1935182803      Timothy Perrett
# Web Development with Apache and Perl     1930110065      Theo Petersen
# Real-World Functional Programming        1933988924      Tomas Petricek with Jon Skeet
# Dependency Injection                     193398855X      Dhanji R. Prasanna
# Understanding Enterprise SOA             1932394591      Eric Pulier and Hugh Taylor, Foreword by Paul Gaffney
# Open-Source ESBs in Action               1933988215      Tijs Rademakers, Jos Dirksen
# DSLs in Boo: Domain-Specific Languages   1933988606      Oren Eini writing as Ayende Rahien
# in .NET
# JUnit Recipes                            1932394230      J. B. Rainsberger with contributions by Scott Stirling
# Clojure in Action                        1935182595      Amit Rathore
# Working with Objects                     134529308       Trygve Reenskaug
# wxPython in Action                       1932394621      Noel Rappin, Robin Dunn
# PHP in Action                            1932394753      Dagfinn Reiersøl with Marcus Baker, Chris Shiflett
# Microsoft Office Essentials              132623129       Ronny Richardson
# Secrets of the JavaScript Ninja          193398869X      John Resig
# The Awesome Power of Java Beans          1884777562      Lawrence H. Rodrigues
# The Cloud at Your Service                1935182528      Jothy Rosenberg, Arthur Mateos
# Personal Videoconferencing               013268327X      Evan Rosen
# Swing Second Edition                     193011088X
# Implementing Elliptic Curve Cryptography 1884777694      Michael Rosing
# SOA Patterns                             1933988266      Arnon Rotem-Gal-Oz
# Hello World!                             1933988495      Warren D. Sande, Carter Sande
# SCBCD Exam Study Kit                     1932394400      Paul Sanghera
# Portlets in Action                       1935182544      Ashish Sarin
# SWT/JFace in Action                      1932394273      Matthew Scarpino, Stephen Holder, Stanford Ng, Laurent Mihalkovic
# Multiprotocol over ATM                   138892709       Andrew Schmidt, Daniel Minoli
# Dependency Injection in .NET             1935182501      Mark Seemann
# Liferay in Action                        193518282X      Richard Sezov, Jr
# Java 3D Programming                      1930110359      Daniel Selman
# JSP Tag Libraries                        193011009X      Gal Shachor, Adam Chace, Magnus Rydin
# Instant Messaging in Java                1930110464      Iain Shigeoka
# Java Applets and Channels Without Progr  1884777392      Ronny Richardson, Michael Shoffner, Marq Singer, Bruce Murray, Ja
# amming                                                   ck Gambol
# PowerShell in Practice                   1935182005      Richard Siddaway
# Making Sense of Java                     132632942       Bruce Simpson, John Mitchell, Brian Christeson, Rehan Zaidi, Jona
#                                                          than Levine
# C# in Depth                              1933988363      Jon Skeet
# C++/CLI in Action                        1932394818      Nishant Sivakumar
# C# in Depth, Second Edition              1935182471      Jon Skeet
# Magical A-Life Avatars                   1884777589      Peter Small
# Becoming Agile                           1933988258      Greg Smith, Ahmed Sidky
# ActiveMQ in Action                       1933988940      Bruce Snyder, Dejan Bosanac, Rob Davies
# Implementing PeopleSoft Financials       138411808       Early Stephens
# SQL Server DMVs in Action                1935182730      Ian W. Stirk
# EJB Cookbook                             1930110944      Benjamin G. Sullins, Mark B. Whipple
# JMX in Action                            1930110561      Benjamin G. Sullins, Mark B. Whipple
# JUnit in Action, Second Edition          1935182021      Petar Tahchiev, Felipe Leme, Vincent Massol, Gary Gregory
# Bitter Java                              193011043X      Bruce A. Tate
# JDK 1.4 Tutorial                         1930110456      Gregory M. Travis
# Bitter EJB                               1930110952      Bruce Tate, Mike Clark, Bob Lee, Patrick Linskey
# iPhone and iPad in Action                1935182587      Brandon Trebitowski, Christopher Allen, Shannon Appelcline
# SQL Server 2005 Reporting Services in A  1932394761      Bret Updegraff
# ction
# Ten Years of UserFriendly.Org            1935182129      JD "Illiad" Frazer
# Graphics Programming with Perl           1930110022      Martien Verbruggen
# XDoclet in Action                        1932394052      Craig Walls, Norman Richards
# Spring in Action                         1932394354      Craig Walls, Ryan Breidenbach
# Spring in Action, Second Edition         1933988134      Craig Walls with Ryan Breidenbach
# Spring in Action, Third Edition          1935182358      Craig Walls
# Java 2 Micro Edition                     1930110332      James P. White, David A. Hemphill
# SharePoint 2010 Web Parts in Action      1935182773      Wictor Wilén
# SharePoint 2010 Workflows in Action      1935182714      Phil Wicklund
# Java Servlets by Example                 188477766X      Alan R. Williamson
# Spring in Practice                       1935182056      Willie Wheeler with Joshua White
# XML Programming with VB and ASP          1884777872      Mark Wilson, Tracey Wilson
# C++ Concurrency in Action                1933988770      Anthony Williams
# Oracle8i Database Administration         1884777783      Noel Yuhanna
# Arduino in Action                        1617290246      Martin Evans, Joshua Noble, Jordan Hochenbaum
# Node.js in Action                        1617290572      Mike Cantelon, Marc Harter, T.J. Holowaychuk, Nathan Rajlich
# SQL Server MVP Deep Dives, Volume 2      1617290475      Kalen Delaney, Louis Davidson, Greg Low, Brad McGehee, Paul Niels
#                                                          en, Paul Randal, Kimberly Tripp
# HTML5 in Action                          1617290491      Rob Crowther, Joe Lennon, Ash Blue, Greg Wanish
# Windows Forms Programming with C#        1930110286
# Windows Forms in Action                  1932394656
# XSLT Quickly                             1930110111
# Event Processing in Action               1935182218
# Objective-C Fundamentals                 1935182536
# ADO.NET Programming                      1930110294
# Location-Aware Applications              1935182331
# WPF in Action with Visual Studio 2008    1933988223
# Web Development with JavaServer Pages,   193011012X
# Second Edition
# IntelliJ IDEA in Action                  1932394443
# The Joy of Clojure                       1935182641
# Spring Integration in Action             1935182439
# Dynamic WAP Application Development      1930110081
# IronPython in Action                     1933988339
# Art of Java Web Development              1932394060
# Java Reflection in Action                1932394184
# Programming Windows Server 2003          1930110987
# Struts Recipes                           1932394249
# Jess in Action                           1930110898
# J2EE and XML Development                 1930110308
# Remote LAN Access                        134944518
# Eclipse in Action                        1930110960
# ASP.NET AJAX in Action                   1933988142
# Ext JS in Action                         1935182110
# Sencha Touch in Action                   1617290378
# DSLs in Action                           1935182455
# Jakarta Commons Online Bookshelf         1932394524

# %% [markdown]
# #### Delete document/s in the collection
#
# * Using delete_one() to delet the first document that satisfies the query/filter in a collection.
#
#     ```
#     from pymongo import MongoClient
#     #connect the client(program) to a mongoDB server
#     try:
#         client = MongoClient("localhost", 27017)
#         print("Connected")
#     except:
#         print("Cannot connect to database")
#
#     mydb = client["mydatabase"]   ## use the database mydatabase
#     mycoll = mydb["customers"]    ## get the collection - customers
#     myquery = {"address": "Canyon 123"}
#     mycoll.delete_one(myquery)
#
#     for document in mycoll.find():
#         print(document)
#     client.close()
#
#     ```
# * Using delete_many() to update the all documents that satisfy the query/filter in a collection.
#
#     ```
#     from pymongo import MongoClient
#         #connect the client(program) to a mongoDB server
#     try:
#         client = MongoClient("localhost", 27017)
#         print("Connected")
#     except:
#         print("Cannot connect to database")
#
#     mydb = client["mydatabase"]   ## use the database mydatabase
#     mycoll = mydb["customers"]    ## get the collection - customers
#     myquery = {"name": "Minnie"}
#     x = mycoll.delete_many(myquery)
#
#     print("No of documents updated : {}".format(x.modified_count))
#
#     client.close()
#     ```
# * Note that mycoll.delete_many({}) will delete all document in the collection.  Use with care!

# %% [markdown]
# #### Exercise 11
#
# Delete the book with isbn = '1930110596' from the collection. Verify that the document is deleted using mongodb shell.

# %%
from pymongo import MongoClient
client = MongoClient("localhost", 27017)
mydb = client["booksdb"]   
mycoll = mydb["books"]
myquery = {"isbn": "1930110596"}
x = mycoll.delete_one(myquery)
client.close()

# %% [markdown]
# #### Exercise 12
#
# Delete all the books that have pageCount=0 from the collection. Verify that the document is deleted using mongodb shell.

# %%
from pymongo import MongoClient
client = MongoClient("localhost", 27017)
mycoll = client["booksdb"]['books']
myquery = {"pageCount":0}
x = mycoll.delete_many(myquery)
client.close()

# %% [markdown]
# #### Other useful methods
#
# * count() - to count the documents a collection.
#     ```
#         mycoll = mydb["cars"]
#         print(mycoll.count())
#
#     ```
# * Using cursor
#     ```
#     cursor = mycoll.find()
#     for x in cursor:
#         print(x)
#     ```

# %% [markdown]
# #### Exercise 13
#
# Verify that the documents with pageCount=0 are deleted by counting the documents with pageCount=0.

# %%
from pymongo import MongoClient
client = MongoClient("localhost", 27017)
mycoll = client["booksdb"]['books']
myquery = {"pageCount":0}
result = mycoll.find(myquery)
if result.count() == 0:
    print("Deleted")
else:
    print("Not deleted")
client.close()
# Out:
# Deleted

# %% [markdown]
# #### Exercise 14
#
# Print out the number of documents left in the **books** collection.

# %%
from pymongo import MongoClient
client = MongoClient("localhost", 27017)
mycoll = client["booksdb"]['books']
result = mycoll.find()
print(result.count())
client.close()
# Out:
# 265

# %% [markdown]
# #### Exercise 15
# Import data in csv file into MongoDB
#
# a. Write Python code to read **language.csv** and insert the records into the collection **language** in database **lang**  of MongoDB.
#
# b. Verify that the data has been inserted.

# %%
import pymongo, csv
client = pymongo.MongoClient("localhost", 27017)
mycoll = client["lang"]["language"]

with open("language.csv") as csv_file:
    csv_reader = csv.DictReader(csv_file, skipinitialspace=True)     #Assumes first line contains keys of dict
                                                                     #assumes delimiter is commas    
    for row in csv_reader:
        mycoll.insert_one(row)

result = mycoll.find()
print("Number of documents added: ", result.count())
client.close()
# Out:
# Number of documents added:  3

# %%
##Testing output of csv.DictReader

import csv

with open("language.csv") as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        print(row, '\n')
    
csv_file.close()
# Out:
# OrderedDict([('Programming language', 'Python'), (' Designed by', ' "Guidoz'), (' Appeared', 'van Rossum"'), (' Extension', ' 1991'), (None, [' py'])])
#
# OrderedDict([('Programming language', 'Java'), (' Designed by', ' "James Gosling"'), (' Appeared', ' 1995'), (' Extension', ' java')])
#
# OrderedDict([('Programming language', 'C++'), (' Designed by', ' "Bjarne Stroustrup"'), (' Appeared', ' 1983'), (' Extension', ' cpp')])

# %%
w = 1
s = 'dwadawd' + str(w)
print(s)
# Out:
# dwadawd1

# %% [markdown]
# #### Exercise 16
# Import data in json file into MongoDB
#
# a. Write Python code to read **intern.json** and insert the records into **intern** collection of database **hrdb** in mongoDB.
#
# b. Verify that the data has been inserted.

# %%
from pymongo import MongoClient
import json
client = MongoClient("localhost", 27017)
mycoll = client["hrdb"]["intern"]
with open('intern.json') as file:
    data = json.load(file)
    for person in data['intern_details']:
        mycoll.insert_one(person)
file.close()

result = mycoll.find()
for r in result:
    print(r)
print("Number of documents added: ", result.count())
client.close()
# Out:
# {'_id': ObjectId('604d6b94e1c7dd1c38deb450'), 'name': 'Tan Tan Tan', 'email': 'tttan@lotsofintern.com', 'designation': 'intern'}
# {'_id': ObjectId('604d6b94e1c7dd1c38deb451'), 'name': 'Lee Lee Lee', 'email': 'lllee@lotsofintern.com', 'designation': 'intern'}
# {'_id': ObjectId('604d6b94e1c7dd1c38deb452'), 'name': 'Ng Ng Ng', 'email': 'nnng@lotsofintern.com', 'designation': 'intern'}
# Number of documents added:  3

# %%
#Testing the output format of json.load method

import json
with open('intern.json', 'r') as file:
    data = json.load(file)
    
for p in data['intern_details']:
    print(p)
# Out:
# {'name': 'Tan Tan Tan', 'email': 'tttan@lotsofintern.com', 'designation': 'intern'}
# {'name': 'Lee Lee Lee', 'email': 'lllee@lotsofintern.com', 'designation': 'intern'}
# {'name': 'Ng Ng Ng', 'email': 'nnng@lotsofintern.com', 'designation': 'intern'}
